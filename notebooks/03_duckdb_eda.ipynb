# %%
import sys
# !{sys.executable} -m pip  install --quiet duckdb duckdb-engine ipython-sql sqlalchemy python-snappy pyarrow memray pandas watermark ipywidgets bs4 polars rich humanize matplotlib
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///my-db.duckdb.db

    read_json_objects('test.json')

# %%
# Table created from CSV file 
# %sql CREATE TABLE goodreads AS SELECT * FROM '/Users/vicki/viberary/viberary/notebooks/goodreads.csv';
# %sql DESCRIBE goodreads;
# Out:
#              column_name column_type null   key default extra
# 0               column00     INTEGER  YES  None    None  None
# 1                   asin     VARCHAR  YES  None    None  None
# 2                authors     VARCHAR  YES  None    None  None
# 3         average_rating      DOUBLE  YES  None    None  None
# 4                book_id     INTEGER  YES  None    None  None
# 5           country_code     VARCHAR  YES  None    None  None
# 6            description     VARCHAR  YES  None    None  None
# 7    edition_information     VARCHAR  YES  None    None  None
# 8                 format     VARCHAR  YES  None    None  None
# 9              image_url     VARCHAR  YES  None    None  None
# 10              is_ebook     BOOLEAN  YES  None    None  None
# 11                  isbn     VARCHAR  YES  None    None  None
# 12                isbn13     VARCHAR  YES  None    None  None
# 13           kindle_asin     VARCHAR  YES  None    None  None
# 14         language_code     VARCHAR  YES  None    None  None
# 15                  link     VARCHAR  YES  None    None  None
# 16             num_pages     INTEGER  YES  None    None  None
# 17       popular_shelves     VARCHAR  YES  None    None  None
# 18       publication_day     INTEGER  YES  None    None  None
# 19     publication_month     INTEGER  YES  None    None  None
# 20      publication_year     INTEGER  YES  None    None  None
# 21             publisher     VARCHAR  YES  None    None  None
# 22         ratings_count     INTEGER  YES  None    None  None
# 23                series     VARCHAR  YES  None    None  None
# 24         similar_books     VARCHAR  YES  None    None  None
# 25    text_reviews_count     INTEGER  YES  None    None  None
# 26                 title     VARCHAR  YES  None    None  None
# 27  title_without_series     VARCHAR  YES  None    None  None
# 28                   url     VARCHAR  YES  None    None  None
# 29               work_id     INTEGER  YES  None    None  None

# %%
# Creating from JSON file
# %sql CREATE TABLE goodreads_json AS SELECT * FROM read_json_objects('/Users/vicki/viberary/viberary/jsonparquet/src/main/resources/goodreads_books.json');
# Out:
#      Count
# 0  2360655

# %%
# Creating from parquet directory
# %sql CREATE TABLE goodreads_pq AS SELECT * FROM '/Users/vicki/Downloads/spark-3.3.1-bin-hadoop3/goodreads_schema/*.parquet';
# Out:
#      Count
# 0  2360655

# %%
# Parquet file does not correctly map column types
# %sql DESCRIBE goodreads_pq;
# Out:
#              column_name                                column_type null  \
# 0                   asin                                    VARCHAR  YES
# 1                authors  STRUCT(author_id VARCHAR, role VARCHAR)[]  YES
# 2         average_rating                                    VARCHAR  YES
# 3                book_id                                    VARCHAR  YES
# 4           country_code                                    VARCHAR  YES
# 5            description                                    VARCHAR  YES
# 6    edition_information                                    VARCHAR  YES
# 7                 format                                    VARCHAR  YES
# 8              image_url                                    VARCHAR  YES
# 9               is_ebook                                    VARCHAR  YES
# 10                  isbn                                    VARCHAR  YES
# 11                isbn13                                    VARCHAR  YES
# 12           kindle_asin                                    VARCHAR  YES
# 13         language_code                                    VARCHAR  YES
# 14                  link                                    VARCHAR  YES
# 15             num_pages                                    VARCHAR  YES
# 16       popular_shelves      STRUCT(count VARCHAR, name VARCHAR)[]  YES
# 17       publication_day                                    VARCHAR  YES
# 18     publication_month                                    VARCHAR  YES
# 19      publication_year                                    VARCHAR  YES
# 20             publisher                                    VARCHAR  YES
# 21         ratings_count                                    VARCHAR  YES
# 22                series                                  VARCHAR[]  YES
# 23         similar_books                                  VARCHAR[]  YES
# 24    text_reviews_count                                    VARCHAR  YES
# 25                 title                                    VARCHAR  YES
# 26  title_without_series                                    VARCHAR  YES
# 27                   url                                    VARCHAR  YES
# 28               work_id                                    VARCHAR  YES
#
#      key default extra
# 0   None    None  None
# 1   None    None  None
# 2   None    None  None
# 3   None    None  None
# 4   None    None  None
# 5   None    None  None
# 6   None    None  None
# 7   None    None  None
# 8   None    None  None
# 9   None    None  None
# 10  None    None  None
# 11  None    None  None
# 12  None    None  None
# 13  None    None  None
# 14  None    None  None
# 15  None    None  None
# 16  None    None  None
# 17  None    None  None
# 18  None    None  None
# 19  None    None  None
# 20  None    None  None
# 21  None    None  None
# 22  None    None  None
# 23  None    None  None
# 24  None    None  None
# 25  None    None  None
# 26  None    None  None
# 27  None    None  None
# 28  None    None  None

# %%
# %sql ALTER TABLE goodreads_pq ALTER book_id TYPE INTEGER;\
ALTER TABLE goodreads_pq ALTER num_pages TYPE INTEGER;
# ALTER TABLE goodreads_pq ALTER ratings_count TYPE INTEGER;\
# ALTER TABLE goodreads_pq ALTER text_reviews_count TYPE INTEGER;\
# ALTER TABLE goodreads_pq ALTER work_id TYPE INTEGER;\
# Out:
# (duckdb.ConversionException) Conversion Error: Could not convert string '' to INT32
# [SQL: ALTER TABLE goodreads_pq ALTER num_pages TYPE INTEGER;]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)

# %%
# %sql DESCRIBE goodreads_pq;

# %%
# %sql select count(*) as total_books from goodreads;
# Out:
#    total_books
# 0      2360655

# %%
# JSON also does not correctly map types
# %sql select * from goodreads_json limit 1;
# Out:
#                                                 json
# 0  {"isbn": "0312853122", "text_reviews_count": "...

# %%
# %sql my_df << SELECT num_pages, count(*) AS total_books \
FROM goodreads \
GROUP BY num_pages \
ORDER BY count(*) desc;
# Out:
# Returning data to local variable my_df

# %%
# %sql my_df << SELECT try_cast(num_pages as INTEGER), count(*) AS total_books \
FROM goodreads_pq \
GROUP BY num_pages \
ORDER BY count(*) desc;
# Out:
# Returning data to local variable my_df

# %%
my_df
# Out:
#       TRY_CAST(num_pages AS INTEGER)  total_books
# 0                                NaN       764133
# 1                               32.0        34947
# 2                              320.0        29945
# 3                              256.0        29859
# 4                              224.0        28978
# ...                              ...          ...
# 2547                         10416.0            1
# 2548                          3203.0            1
# 2549                          1852.0            1
# 2550                          5012.0            1
# 2551                          2871.0            1
#
# [2552 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

my_df.plot(x='num_pages', y='total_books', kind='scatter')
# Out:
# <AxesSubplot:xlabel='num_pages', ylabel='total_books'>

# %%
# Throw out outliers

# %%
# Inspect CSV data
# %sql select * from goodreads limit 10;
# Out:
#    column00        asin                                            authors  \
# 0         0        None              [{'author_id': '604031', 'role': ''}]
# 1         1        None              [{'author_id': '626222', 'role': ''}]
# 2         2  B00071IKUY               [{'author_id': '10333', 'role': ''}]
# 3         3        None                [{'author_id': '9212', 'role': ''}]
# 4         4        None              [{'author_id': '149918', 'role': ''}]
# 5         5        None             [{'author_id': '3041852', 'role': ''}]
# 6         6        None              [{'author_id': '215594', 'role': ''}]
# 7         7        None               [{'author_id': '19158', 'role': ''}]
# 8         8        None             [{'author_id': '5807700', 'role': ''}]
# 9         9        None  [{'author_id': '2983296', 'role': ''}\n {'auth...
#
#    average_rating   book_id country_code  \
# 0            4.00   5333265           US
# 1            3.23   1333909           US
# 2            4.03   7327624           US
# 3            3.49   6066819           US
# 4            3.40    287140           US
# 5            4.13    287141           US
# 6            4.38    378460           US
# 7            4.22   6066812           US
# 8            3.86  34883016           US
# 9            3.81    287149           US
#
#                                          description edition_information  \
# 0                                               None                None
# 1  Anita Diamant's international bestseller "The ...            Abridged
# 2  Omnibus book club edition containing the Ladie...   Book Club Edition
# 3  Addie Downs and Valerie Adler were eight when ...                None
# 4                                               None                None
# 5  Relates in vigorous prose the tale of Aeneas, ...                None
# 6                                               None                None
# 7  To Kara's astonishment, she discovers that a p...                None
# 8  Secrets. Sometimes keeping them in confidence ...                None
# 9  Wisdom, humor, and dark observations by the fo...                None
#
#       format                                          image_url  ...  \
# 0  Paperback  https://images.gr-assets.com/books/1310220028m...  ...
# 1   Audio CD  https://s.gr-assets.com/assets/nophoto/book/11...  ...
# 2  Hardcover  https://images.gr-assets.com/books/1304100136m...  ...
# 3  Hardcover  https://s.gr-assets.com/assets/nophoto/book/11...  ...
# 4       None  https://images.gr-assets.com/books/1413219371m...  ...
# 5  Paperback  https://s.gr-assets.com/assets/nophoto/book/11...  ...
# 6  Paperback  https://s.gr-assets.com/assets/nophoto/book/11...  ...
# 7  Paperback  https://images.gr-assets.com/books/1316637798m...  ...
# 8      ebook  https://images.gr-assets.com/books/1493525974m...  ...
# 9  Paperback  https://images.gr-assets.com/books/1328768789m...  ...
#
#    publication_year                 publisher ratings_count      series  \
# 0            1984.0        St. Martin's Press             3          []
# 1            2001.0    Simon & Schuster Audio            10          []
# 2            1987.0    Nelson Doubleday, Inc.           140  ['189911']
# 3            2009.0               Atria Books         51184          []
# 4               NaN                      None            15          []
# 5            2006.0      Yesterday's Classics            46          []
# 6            1979.0  Berkley Publishing Group            12          []
# 7            2009.0                Seven Seas            98  ['151854']
# 8            2017.0   Gone Writing Publishing             5          []
# 9            2000.0               Feral House           986          []
#
#                                        similar_books text_reviews_count  \
# 0                                                 []                  1
# 1  ['8709549' '17074050' '28937' '158816' '228563...                  6
# 2  ['19997' '828466' '1569323' '425389' '1176674'...                  7
# 3  ['6604176' '6054190' '2285777' '82641' '756945...               3282
# 4                                                 []                  5
# 5                                                 []                  7
# 6                                                 []                  4
# 7  ['948696' '439885' '274955' '12978730' '372986...                  6
# 8                                                 []                  4
# 9  ['287151' '1104760' '1172822' '440292' '287082...                 39
#
#                                                title  \
# 0                        W.C. Fields: A Life on Film
# 1                                        Good Harbor
# 2  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3                               Best Friends Forever
# 4  Runic Astrology: Starcraft and Timekeeping in ...
# 5                      The Aeneid for Boys and Girls
# 6                              The Wanting of Levine
# 7  All's Fairy in Love and War (Avalon: Web of Ma...
# 8                  Playmaker: A Venom Series Novella
# 9                               The Devil's Notebook
#
#                                 title_without_series  \
# 0                        W.C. Fields: A Life on Film
# 1                                        Good Harbor
# 2  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3                               Best Friends Forever
# 4  Runic Astrology: Starcraft and Timekeeping in ...
# 5                      The Aeneid for Boys and Girls
# 6                              The Wanting of Levine
# 7  All's Fairy in Love and War (Avalon: Web of Ma...
# 8                  Playmaker: A Venom Series Novella
# 9                               The Devil's Notebook
#
#                                                  url   work_id
# 0  https://www.goodreads.com/book/show/5333265-w-...   5400751
# 1  https://www.goodreads.com/book/show/1333909.Go...   1323437
# 2  https://www.goodreads.com/book/show/7327624-th...   8948723
# 3  https://www.goodreads.com/book/show/6066819-be...   6243154
# 4  https://www.goodreads.com/book/show/287140.Run...    278577
# 5  https://www.goodreads.com/book/show/287141.The...    278578
# 6  https://www.goodreads.com/book/show/378460.The...    368291
# 7  https://www.goodreads.com/book/show/6066812-al...    701117
# 8  https://www.goodreads.com/book/show/34883016-p...  56135087
# 9  https://www.goodreads.com/book/show/287149.The...    278586
#
# [10 rows x 30 columns]
