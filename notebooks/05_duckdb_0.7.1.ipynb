# %%
import sys

# !{sys.executable} -W ignore:DEPRECATION -m pip install --quiet duckdb==0.7.1 \
duckdb-engine \
watermark \
jupysql \
sqlalchemy \
python-snappy \
pyarrow \
memray \
pandas \
ipywidgets  \
matplotlib \
gensim \
nltk

# %%
import duckdb
import re
import pandas as pd
import shlex
import string
from time import time

from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from gensim.test.utils import datapath
from gensim import utils

import multiprocessing

# %%
cores = multiprocessing.cpu_count()
cores
# Out:
# 16

# %%
import logging 
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
# %load_ext watermark
# Duckdb 0.7.0 offers a bunch of new JSON stuff that I want to test out, checking to see I have the latest
# https://duckdb.org/2023/03/03/json.html
# %watermark --iversions
# Out:
# duckdb : 0.7.1
# sys    : 3.9.12 (main, Mar 26 2022, 15:51:13)
# [Clang 12.0.0 (clang-1200.0.32.29)]
# re     : 2.2.1
# pandas : 1.5.3
# logging: 0.5.1.2

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# Create new DB or load existing https://duckdb.org/docs/guides/python/jupyter.html
# %sql duckdb:///viberary.duckdb

# %%
# %sql DESCRIBE select * from read_json_auto('/Users/vicki/viberary/viberary/data/goodreads_books.json',lines='true');
# Out:
#              column_name                                 column_type null  \
# 0                   isbn                                     VARCHAR  YES
# 1     text_reviews_count                                     VARCHAR  YES
# 2                 series                                    BIGINT[]  YES
# 3           country_code                                     VARCHAR  YES
# 4          language_code                                     VARCHAR  YES
# 5        popular_shelves      STRUCT(count BIGINT, "name" VARCHAR)[]  YES
# 6                   asin                                     VARCHAR  YES
# 7               is_ebook                                     VARCHAR  YES
# 8         average_rating                                     VARCHAR  YES
# 9            kindle_asin                                     VARCHAR  YES
# 10         similar_books                                    BIGINT[]  YES
# 11           description                                     VARCHAR  YES
# 12                format                                     VARCHAR  YES
# 13                  link                                     VARCHAR  YES
# 14               authors  STRUCT(author_id BIGINT, "role" VARCHAR)[]  YES
# 15             publisher                                     VARCHAR  YES
# 16             num_pages                                     VARCHAR  YES
# 17       publication_day                                     VARCHAR  YES
# 18                isbn13                                     VARCHAR  YES
# 19     publication_month                                     VARCHAR  YES
# 20   edition_information                                     VARCHAR  YES
# 21      publication_year                                     VARCHAR  YES
# 22                   url                                     VARCHAR  YES
# 23             image_url                                     VARCHAR  YES
# 24               book_id                                      BIGINT  YES
# 25         ratings_count                                     VARCHAR  YES
# 26               work_id                                     VARCHAR  YES
# 27                 title                                     VARCHAR  YES
# 28  title_without_series                                     VARCHAR  YES
#
#      key default extra
# 0   None    None  None
# 1   None    None  None
# 2   None    None  None
# 3   None    None  None
# 4   None    None  None
# 5   None    None  None
# 6   None    None  None
# 7   None    None  None
# 8   None    None  None
# 9   None    None  None
# 10  None    None  None
# 11  None    None  None
# 12  None    None  None
# 13  None    None  None
# 14  None    None  None
# 15  None    None  None
# 16  None    None  None
# 17  None    None  None
# 18  None    None  None
# 19  None    None  None
# 20  None    None  None
# 21  None    None  None
# 22  None    None  None
# 23  None    None  None
# 24  None    None  None
# 25  None    None  None
# 26  None    None  None
# 27  None    None  None
# 28  None    None  None

# %%
# Create table in DuckDB
# %sql CREATE TABLE goodreads as select * from read_json_auto('/Users/vicki/viberary/viberary/data/goodreads_books.json',lines='true');
# Out:
# (duckdb.CatalogException) Catalog Error: Table with name "goodreads" already exists!
# [SQL: CREATE TABLE goodreads as select * from read_json_auto('/Users/vicki/viberary/viberary/data/goodreads_books.json',lines='true');]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %sql select book_id, title, popular_shelves as ps, description from goodreads limit 10;
# Out:
#     book_id                                              title  \
# 0   5333265                        W.C. Fields: A Life on Film
# 1   1333909                                        Good Harbor
# 2   7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3   6066819                               Best Friends Forever
# 4    287140  Runic Astrology: Starcraft and Timekeeping in ...
# 5    287141                      The Aeneid for Boys and Girls
# 6    378460                              The Wanting of Levine
# 7   6066812  All's Fairy in Love and War (Avalon: Web of Ma...
# 8  34883016                  Playmaker: A Venom Series Novella
# 9    287149                               The Devil's Notebook
#
#                                                   ps  \
# 0  [{'count': 3, 'name': 'to-read'}, {'count': 1,...
# 1  [{'count': 2634, 'name': 'to-read'}, {'count':...
# 2  [{'count': 58, 'name': 'to-read'}, {'count': 1...
# 3  [{'count': 7615, 'name': 'to-read'}, {'count':...
# 4  [{'count': 32, 'name': 'to-read'}, {'count': 3...
# 5  [{'count': 56, 'name': 'to-read'}, {'count': 1...
# 6  [{'count': 14, 'name': 'to-read'}, {'count': 1...
# 7  [{'count': 515, 'name': 'to-read'}, {'count': ...
# 8  [{'count': 4, 'name': 'to-read'}, {'count': 1,...
# 9  [{'count': 961, 'name': 'to-read'}, {'count': ...
#
#                                          description
# 0
# 1  Anita Diamant's international bestseller "The ...
# 2  Omnibus book club edition containing the Ladie...
# 3  Addie Downs and Valerie Adler were eight when ...
# 4
# 5  Relates in vigorous prose the tale of Aeneas, ...
# 6
# 7  To Kara's astonishment, she discovers that a p...
# 8  Secrets. Sometimes keeping them in confidence ...
# 9  Wisdom, humor, and dark observations by the fo...

# %%
# Let's start with title and description as our sentence feature

# we have to connect with pyscopg because the sql magic doesn't allow string literal concatenation due to Posix=
con = duckdb.connect('viberary.duckdb')

# Query the existing goodreads table and clean up formatting
sentences = con.sql("""select concat_ws(' ' , lower(regexp_replace(title, '[[:^alpha:]]',' ','g')), \
                    lower(regexp_replace(description, '[[:^alpha:]]',' ','g'))) as sentence from goodreads;""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='100%'), style=ProgressStyle(bar_color='black'))

# %%
# Each sentence is a single book
sentences.head()
# Out:
#                                             sentence
# 0                       w c  fields  a life on film
# 1  good harbor anita diamant s international best...
# 2  the unschooled wizard  sun wolf and starhawk  ...
# 3  best friends forever addie downs and valerie a...
# 4  runic astrology  starcraft and timekeeping in ...

# %%
# Check for nulls
sentences.isnull().sum()
# Out:
# sentence    0
# dtype: int64

# %%
sentences.to_csv('sentences.csv', index=False)

# %%
! cat sentences.csv | head
# Out:
# sentence
# w c  fields  a life on film
# INFO - 15:33:50: PROGRESS: at sentence #2270000, processed 265229088 words, keeping 2581452 word types
# INFO - 15:33:51: PROGRESS: at sentence #2280000, processed 266397952 words, keeping 2587400 word types
# INFO - 15:33:53: PROGRESS: at sentence #2290000, processed 267567449 words, keeping 2593346 word types
# INFO - 15:33:54: PROGRESS: at sentence #2300000, processed 268722356 words, keeping 2599264 word types
# INFO - 15:33:56: PROGRESS: at sentence #2310000, processed 269896176 words, keeping 2605074 word types
# INFO - 15:33:57: PROGRESS: at sentence #2320000, processed 271055781 words, keeping 2611174 word types
# INFO - 15:33:59: PROGRESS: at sentence #2330000, processed 272213045 words, keeping 2617235 word types
# INFO - 15:34:00: PROGRESS: at sentence #2340000, processed 273380700 words, keeping 2623397 word types
# INFO - 15:34:02: PROGRESS: at sentence #2350000, processed 274546231 words, keeping 2629395 word types
# INFO - 15:34:03: PROGRESS: at sentence #2360000, processed 275719560 words, keeping 2635205 word types
# INFO - 15:34:03: collected 2635551 word types from a corpus of 275794650 raw words and 2360656 sentences
# INFO - 15:34:03: Creating a fresh vocabulary
# INFO - 15:34:05: Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 245474 unique words (9.31% of original 2635551, drops 2390077)', 'datetime': '2023-03-24T15:34:05.403287', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# INFO - 15:34:05: Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 268992999 word corpus (97.53% of original 275794650, drops 6801651)', 'datetime': '2023-03-24T15:34:05.403901', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# INFO - 15:34:06: deleting the raw counts dictionary of 2635551 items
# INFO - 15:34:06: sample=6e-05 downsamples 690 most-common words
# INFO - 15:34:06: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 158340100.72092313 word corpus (58.9%% of prior 268992999)', 'datetime': '2023-03-24T15:34:06.676646', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# INFO - 15:34:08: estimated required memory for 245474 words and 300 dimensions: 711874600 bytes
# INFO - 15:34:08: resetting layer weights
# INFO - 15:34:09: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-03-24T15:34:09.090071', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# Time to build vocab: 5.85 mins

# %%
t = time()

w2v_model.train(sentence_iterator, total_examples=w2v_model.corpus_count, epochs=10, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# WARNING - 15:36:32: Effective 'alpha' higher than previous training cycles
# INFO - 15:36:32: Word2Vec lifecycle event {'msg': 'training model with 15 workers on 245474 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2 shrink_windows=True', 'datetime': '2023-03-24T15:36:32.788763', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# INFO - 15:36:33: EPOCH 0 - PROGRESS: at 50.83% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:34: EPOCH 0: training on 2360655 raw words (0 effective words) took 2.0s, 0 effective words/s
# WARNING - 15:36:34: EPOCH 0: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:35: EPOCH 1 - PROGRESS: at 49.56% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:36: EPOCH 1 - PROGRESS: at 97.01% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:36: EPOCH 1: training on 2360655 raw words (0 effective words) took 2.1s, 0 effective words/s
# WARNING - 15:36:36: EPOCH 1: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:37: EPOCH 2 - PROGRESS: at 47.87% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:38: EPOCH 2 - PROGRESS: at 97.01% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:38: EPOCH 2: training on 2360655 raw words (0 effective words) took 2.1s, 0 effective words/s
# WARNING - 15:36:38: EPOCH 2: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:39: EPOCH 3 - PROGRESS: at 51.68% examples, 0 words/s, in_qsize 0, out_qsize 2
# INFO - 15:36:40: EPOCH 3: training on 2360655 raw words (0 effective words) took 2.0s, 0 effective words/s
# WARNING - 15:36:40: EPOCH 3: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:41: EPOCH 4 - PROGRESS: at 51.68% examples, 0 words/s, in_qsize 2, out_qsize 3
# INFO - 15:36:42: EPOCH 4: training on 2360655 raw words (0 effective words) took 2.0s, 0 effective words/s
# WARNING - 15:36:42: EPOCH 4: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:43: EPOCH 5 - PROGRESS: at 49.99% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:44: EPOCH 5: training on 2360655 raw words (0 effective words) took 2.0s, 0 effective words/s
# WARNING - 15:36:44: EPOCH 5: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:45: EPOCH 6 - PROGRESS: at 50.41% examples, 0 words/s, in_qsize 0, out_qsize 3
# INFO - 15:36:46: EPOCH 6: training on 2360655 raw words (0 effective words) took 2.0s, 0 effective words/s
# WARNING - 15:36:46: EPOCH 6: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:47: EPOCH 7 - PROGRESS: at 45.75% examples, 0 words/s, in_qsize 0, out_qsize 2
# INFO - 15:36:48: EPOCH 7 - PROGRESS: at 94.04% examples, 0 words/s, in_qsize 0, out_qsize 1
# INFO - 15:36:49: EPOCH 7: training on 2360655 raw words (0 effective words) took 2.1s, 0 effective words/s
# WARNING - 15:36:49: EPOCH 7: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:50: EPOCH 8 - PROGRESS: at 48.29% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:51: EPOCH 8 - PROGRESS: at 96.58% examples, 0 words/s, in_qsize 0, out_qsize 3
# INFO - 15:36:51: EPOCH 8: training on 2360655 raw words (0 effective words) took 2.1s, 0 effective words/s
# WARNING - 15:36:51: EPOCH 8: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:52: EPOCH 9 - PROGRESS: at 47.87% examples, 0 words/s, in_qsize 0, out_qsize 0
# INFO - 15:36:53: EPOCH 9 - PROGRESS: at 93.62% examples, 0 words/s, in_qsize 1, out_qsize 1
# INFO - 15:36:53: EPOCH 9: training on 2360655 raw words (0 effective words) took 2.1s, 0 effective words/s
# WARNING - 15:36:53: EPOCH 9: supplied example count (2360655) did not equal expected count (2360656)
# INFO - 15:36:53: Word2Vec lifecycle event {'msg': 'training on 23606550 raw words (0 effective words) took 20.4s, 0 effective words/s', 'datetime': '2023-03-24T15:36:53.235568', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# Time to train the model: 0.34 mins

# %%
# Saving and checkpointing
w2v_model.save("word2vec.model")
# Out:
# INFO - 15:38:06: Word2Vec lifecycle event {'fname_or_handle': 'word2vec.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-03-24T15:38:06.631816', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'saving'}
# INFO - 15:38:06: storing np array 'vectors' to word2vec.model.wv.vectors.npy
# INFO - 15:38:07: storing np array 'syn1neg' to word2vec.model.syn1neg.npy
# INFO - 15:38:07: not storing attribute cum_table
# INFO - 15:38:07: saved word2vec.model

# %%
word_vectors = w2v_model.wv
word_vectors.save('vectors.kv')
# Out:
# INFO - 15:38:09: KeyedVectors lifecycle event {'fname_or_handle': 'vectors.kv', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-03-24T15:38:09.623181', 'gensim': '4.3.1', 'python': '3.9.12 (main, Mar 26 2022, 15:51:13) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'saving'}
# INFO - 15:38:09: storing np array 'vectors' to vectors.kv.vectors.npy
# INFO - 15:38:10: saved vectors.kv

# %%
w2v_model.wv.most_similar(["language"])
# Out:
# [('plataformas', 0.2486429214477539),
#  ('ruminate', 0.24250322580337524),
#  ('tenues', 0.2424517124891281),
#  ('himari', 0.24068190157413483),
#  ('mtrf', 0.23997090756893158),
#  ('viimeiset', 0.23300020396709442),
#  ('wlqrt', 0.23264293372631073),
#  ('capables', 0.2300754338502884),
#  ('parvulescu', 0.22820627689361572),
#  ('yalda', 0.22673505544662476)]

# %%
vocab_len = len(w2v_model.wv)
vocab_len
# Out:
# 245474

# %%
w2v_model.wv.index_to_key
# Out:
# ['the',
#  'and',
#  'of',
#  'to',
#  'in',
#  'is',
#  'her',
#  'for',
#  'his',
#  'with',
#  'that',
#  'he',
#  'she',
#  'as',
#  'on',
#  'it',
#  'but',
#  'from',
#  'an',
#  'de',
#  'this',
#  'by',
#  'has',
#  'their',
#  'one',
#  'be',
#  'who',
#  'are',
#  'life',
#  'when',
#  'at',
#  'you',
#  'they',
#  'will',
#  'all',
#  'was',
#  'new',
#  'can',
#  'la',
#  'book',
#  'have',
#  'world',
#  'what',
#  'into',
#  'him',
#  'not',
#  'or',
#  'love',
#  'more',
#  'about',
#  'how',
#  'out',
#  'no',
#  'up',
#  'only',
#  'time',
#  'story',
#  'man',
#  'un',
#  'di',
#  'first',
#  'them',
#  'en',
#  'most',
#  'your',
#  'que',
#  'been',
#  'than',
#  'so',
#  'do',
#  'now',
#  'family',
#  'just',
#  'there',
#  'years',
#  'after',
#  'own',
#  'if',
#  'two',
#  'find',
#  'its',
#  'way',
#  'through',
#  'like',
#  'even',
#  'we',
#  'other',
#  'never',
#  'had',
#  'se',
#  'my',
#  'old',
#  'which',
#  'where',
#  'over',
#  'back',
#  'young',
#  'people',
#  'el',
#  'make',
#  'series',
#  'best',
#  'war',
#  'our',
#  'author',
#  'before',
#  'una',
#  'woman',
#  'home',
#  'ever',
#  'get',
#  'these',
#  'work',
#  'must',
#  'heart',
#  'between',
#  'day',
#  'novel',
#  'help',
#  'also',
#  'year',
#  'history',
#  'il',
#  'could',
#  'stories',
#  'would',
#  'some',
#  'past',
#  'each',
#  'le',
#  'both',
#  'me',
#  'long',
#  'well',
#  'da',
#  'lives',
#  'come',
#  'every',
#  'death',
#  'then',
#  'while',
#  'were',
#  'many',
#  'little',
#  'take',
#  'down',
#  'father',
#  'che',
#  'being',
#  'del',
#  'us',
#  'know',
#  'finds',
#  'secret',
#  'die',
#  'everything',
#  'too',
#  'men',
#  'until',
#  'together',
#  'girl',
#  'three',
#  'good',
#  'great',
#  'night',
#  'na',
#  'much',
#  'last',
#  'very',
#  'women',
#  'american',
#  'mother',
#  'may',
#  'friends',
#  'city',
#  'dark',
#  'those',
#  'si',
#  'off',
#  'go',
#  'readers',
#  'friend',
#  'children',
#  'human',
#  'things',
#  'once',
#  'con',
#  've',
#  'los',
#  'school',
#  'herself',
#  'power',
#  'something',
#  'again',
#  'york',
#  'himself',
#  'true',
#  'su',
#  'wants',
#  'set',
#  'why',
#  'away',
#  'son',
#  'place',
#  'town',
#  'against',
#  'become',
#  'll',
#  'any',
#  'knows',
#  'yang',
#  'doesn',
#  'takes',
#  'part',
#  'another',
#  'yet',
#  'books',
#  'dead',
#  'end',
#  'made',
#  'high',
#  'around',
#  'always',
#  'real',
#  'et',
#  'read',
#  're',
#  'comes',
#  'secrets',
#  'still',
#  'god',
#  'romance',
#  'keep',
#  'dan',
#  'want',
#  'house',
#  'behind',
#  'future',
#  'see',
#  'beautiful',
#  'right',
#  'found',
#  'left',
#  'such',
#  'face',
#  'full',
#  'does',
#  'soon',
#  'guide',
#  'lost',
#  'und',
#  'journey',
#  'living',
#  'fy',
#  'murder',
#  'times',
#  'der',
#  'century',
#  'truth',
#  'nothing',
#  'including',
#  'mystery',
#  'edition',
#  'need',
#  'boy',
#  'tale',
#  'learn',
#  'america',
#  'perfect',
#  'far',
#  'save',
#  'under',
#  'don',
#  'without',
#  'change',
#  'live',
#  'since',
#  'collection',
#  'mn',
#  'known',
#  'short',
#  'small',
#  'might',
#  'art',
#  'thing',
#  'written',
#  'es',
#  'al',
#  'powerful',
#  'because',
#  'black',
#  'body',
#  'wife',
#  'makes',
#  'going',
#  'child',
#  'per',
#  'personal',
#  'para',
#  'here',
#  'daughter',
#  'age',
#  'four',
#  'job',
#  'mind',
#  'second',
#  'enough',
#  'thought',
#  'fiction',
#  'really',
#  'finally',
#  'country',
#  'husband',
#  'business',
#  'por',
#  'brother',
#  'john',
#  'modern',
#  'big',
#  'isn',
#  'whose',
#  'different',
#  'chance',
#  'begins',
#  'mysterious',
#  'along',
#  'same',
#  'during',
#  'non',
#  'self',
#  'van',
#  'hard',
#  'king',
#  'look',
#  'hope',
#  'discover',
#  'relationship',
#  'today',
#  'adventure',
#  'next',
#  'someone',
#  'earth',
#  'magic',
#  'dangerous',
#  'las',
#  'les',
#  'case',
#  'days',
#  'turn',
#  'dreams',
#  'needs',
#  'parents',
#  'everyone',
#  'ha',
#  'five',
#  'volume',
#  'seems',
#  'characters',
#  'becomes',
#  'dr',
#  'use',
#  'den',
#  'sister',
#  'making',
#  'free',
#  'bad',
#  'forever',
#  'killer',
#  'discovers',
#  'better',
#  'writing',
#  'science',
#  'should',
#  'social',
#  'determined',
#  'stop',
#  'sex',
#  'though',
#  'des',
#  'did',
#  'give',
#  'marriage',
#  'few',
#  'let',
#  'within',
#  'across',
#  'ancient',
#  'experience',
#  'ten',
#  'others',
#  'easy',
#  'alone',
#  'turns',
#  'put',
#  'side',
#  'battle',
#  'blood',
#  'della',
#  'sa',
#  'order',
#  'london',
#  'words',
#  'anything',
#  'star',
#  'offers',
#  'meets',
#  'career',
#  'game',
#  'published',
#  'een',
#  'anyone',
#  'name',
#  'bir',
#  'um',
#  'society',
#  'bestselling',
#  'light',
#  'christmas',
#  'important',
#  'deep',
#  'political',
#  'white',
#  'ways',
#  'land',
#  'fight',
#  'show',
#  'eyes',
#  'run',
#  'sie',
#  'called',
#  'hot',
#  'ago',
#  'includes',
#  'start',
#  'shows',
#  'crime',
#  'evil',
#  'simple',
#  'control',
#  'tales',
#  'bring',
#  'beyond',
#  'er',
#  'lo',
#  'looking',
#  'original',
#  'fall',
#  'works',
#  'think',
#  'classic',
#  'won',
#  'later',
#  'passion',
#  'themselves',
#  'award',
#  'com',
#  'events',
#  'questions',
#  'summer',
#  'play',
#  'working',
#  'gets',
#  'english',
#  'met',
#  'dream',
#  'sure',
#  'writer',
#  'person',
#  'special',
#  'soul',
#  'language',
#  'plan',
#  'among',
#  'head',
#  'kai',
#  'reading',
#  'jack',
#  'ja',
#  'group',
#  'step',
#  'twenty',
#  'forced',
#  'mas',
#  'strange',
#  'ma',
#  'inside',
#  'complete',
#  'meet',
#  'early',
#  'goes',
#  'detective',
#  'kind',
#  'reader',
#  'une',
#  'however',
#  'return',
#  'team',
#  'money',
#  'trying',
#  'nature',
#  'care',
#  'coming',
#  'james',
#  'means',
#  'wrong',
#  'ne',
#  'often',
#  'sexy',
#  'search',
#  'como',
#  'te',
#  'fun',
#  'six',
#  'escape',
#  'danger',
#  'culture',
#  'getting',
#  'brings',
#  'leave',
#  'trust',
#  'upon',
#  'tell',
#  'loves',
#  'knew',
#  'fate',
#  'former',
#  'master',
#  'du',
#  'st',
#  'tells',
#  'having',
#  'unique',
#  'rich',
#  'course',
#  'police',
#  'historical',
#  'david',
#  'mission',
#  'faith',
#  'close',
#  'greatest',
#  'popular',
#  'able',
#  'het',
#  'je',
#  'wild',
#  'based',
#  'fantasy',
#  'born',
#  'est',
#  'hand',
#  'winning',
#  'island',
#  'sua',
#  'th',
#  'survive',
#  'girls',
#  'protect',
#  'ex',
#  'information',
#  'red',
#  'whole',
#  'fire',
#  'middle',
#  'told',
#  'food',
#  'forces',
#  'beauty',
#  'wanted',
#  'almost',
#  'local',
#  'baby',
#  'call',
#  'missing',
#  'hidden',
#  'follow',
#  'vampire',
#  'stay',
#  'hands',
#  'top',
#  'sometimes',
#  'present',
#  'late',
#  'loved',
#  'whether',
#  'feel',
#  'deadly',
#  'understand',
#  'key',
#  'believe',
#  'final',
#  'used',
#  'desire',
#  'state',
#  'college',
#  'mr',
#  'got',
#  'action',
#  'och',
#  'das',
#  'half',
#  'single',
#  'didn',
#  'force',
#  'fear',
#  'lead',
#  'ready',
#  'lady',
#  'moment',
#  'taking',
#  'seen',
#  'sense',
#  'finding',
#  'race',
#  'filled',
#  'happy',
#  'famous',
#  'choice',
#  'hell',
#  'matter',
#  'music',
#  'turned',
#  'lies',
#  'taken',
#  'clear',
#  'childhood',
#  'contains',
#  'growing',
#  'england',
#  'law',
#  'community',
#  'reality',
#  'spirit',
#  'learns',
#  'especially',
#  'say',
#  'west',
#  'research',
#  'strong',
#  'major',
#  'tou',
#  'public',
#  'move',
#  'provides',
#  'contemporary',
#  'cover',
#  'uma',
#  'suddenly',
#  'using',
#  'beginning',
#  'question',
#  'space',
#  'fast',
#  'queen',
#  'account',
#  'extraordinary',
#  'came',
#  'dog',
#  'sexual',
#  'else',
#  'door',
#  'line',
#  'form',
#  'students',
#  'handsome',
#  'desperate',
#  'novels',
#  'michael',
#  'friendship',
#  'named',
#  'lord',
#  'sea',
#  'broken',
#  'text',
#  'kids',
#  'success',
#  'trouble',
#  'qui',
#  'understanding',
#  'stand',
#  'literary',
#  'running',
#  'plans',
#  'unexpected',
#  'study',
#  'create',
#  'problem',
#  'apart',
#  'begin',
#  'became',
#  'seven',
#  'page',
#  'poems',
#  'era',
#  'states',
#  'idea',
#  'club',
#  'alive',
#  'writers',
#  'break',
#  'kill',
#  'moving',
#  'style',
#  'adventures',
#  'plus',
#  'fact',
#  'gives',
#  'roman',
#  'fans',
#  'em',
#  'south',
#  'gone',
#  'despite',
#  'road',
#  'peace',
#  'enemy',
#  'path',
#  'quest',
#  'open',
#  'safe',
#  'changed',
#  'north',
#  'planet',
#  'freedom',
#  'changes',
#  'literature',
#  'word',
#  'united',
#  'leads',
#  'loss',
#  'company',
#  'cold',
#  'fascinating',
#  'instead',
#  'national',
#  'beloved',
#  'zu',
#  'point',
#  'struggle',
#  'eye',
#  'ideas',
#  'less',
#  'lm',
#  'introduction',
#  'hero',
#  'church',
#  'role',
#  'class',
#  'sin',
#  'vida',
#  'falls',
#  'travel',
#  'entire',
#  'piu',
#  'ist',
#  'authors',
#  'british',
#  'og',
#  'possible',
#  'drawn',
#  'share',
#  'dans',
#  'successful',
#  'street',
#  'sus',
#  'learning',
#  'reveals',
#  'pages',
#  'sweet',
#  'government',
#  'blue',
#  'ze',
#  'funny',
#  'quickly',
#  'esta',
#  'cat',
#  'private',
#  'thriller',
#  'party',
#  'brought',
#  'color',
#  'already',
#  'answers',
#  'voice',
#  'room',
#  'explores',
#  'international',
#  'risk',
#  'rock',
#  'als',
#  'itself',
#  'prince',
#  'poetry',
#  'throughout',
#  'humor',
#  'mary',
#  'recipes',
#  'issues',
#  'violence',
#  'problems',
#  'robert',
#  'grace',
#  'army',
#  'given',
#  'months',
#  'darkness',
#  'alla',
#  'christian',
#  'returns',
#  'brilliant',
#  'sets',
#  'knowledge',
#  'am',
#  'rules',
#  'practical',
#  'military',
#  'happens',
#  'decide',
#  'lived',
#  'following',
#  'destroy',
#  'created',
#  'truly',
#  'von',
#  'som',
#  'join',
#  'guy',
#  'gift',
#  'ein',
#  'co',
#  'killed',
#  'caught',
#  'artist',
#  'spiritual',
#  'magical',
#  'available',
#  'mark',
#  'identity',
#  'boys',
#  'romantic',
#  'looks',
#  'doctor',
#  'sam',
#  'stranger',
#  'features',
#  'health',
#  'han',
#  'hold',
#  'system',
#  'mais',
#  'memories',
#  'nearly',
#  'seem',
#  'film',
#  'brothers',
#  'feelings',
#  'justice',
#  'deal',
#  'dengan',
#  'powers',
#  'falling',
#  'trilogy',
#  'process',
#  'thinks',
#  'horror',
#  'leading',
#  'tes',
#  'lover',
#  'leaving',
#  'boyfriend',
#  'common',
#  'worse',
#  'revenge',
#  'relationships',
#  'empire',
#  'epic',
#  'peter',
#  'student',
#  'os',
#  'done',
#  'feels',
#  'realizes',
#  'wedding',
#  'fresh',
#  'ii',
#  'win',
#  'fighting',
#  'illustrations',
#  'sees',
#  'om',
#  'village',
#  'pain',
#  'third',
#  'paul',
#  'offer',
#  'chapter',
#  'pero',
#  'lot',
#  'took',
#  'sich',
#  'adult',
#  'french',
#  'alex',
#  'dragon',
#  'struggles',
#  'ultimate',
#  'skills',
#  'experiences',
#  'jane',
#  'cultural',
#  'elle',
#  'least',
#  'leaves',
#  'natural',
#  'nation',
#  'married',
#  'doing',
#  'outside',
#  'terrible',
#  'ar',
#  'starts',
#  'try',
#  'character',
#  'agent',
#  'memory',
#  'politics',
#  'ben',
#  'pa',
#  'figure',
#  'prove',
#  'george',
#  'longer',
#  'happened',
#  'rest',
#  'paris',
#  'rise',
#  'dei',
#  'tragedy',
#  'za',
#  'tom',
#  'ta',
#  'lose',
#  'rather',
#  'survival',
#  'green',
#  'wolf',
#  'water',
#  'places',
#  'civil',
#  'discovery',
#  'attention',
#  'thomas',
#  'nel',
#  'pour',
#  'edge',
#  'said',
#  'illustrated',
#  'spent',
#  'media',
#  'cannot',
#  'destiny',
#  'university',
#  'remarkable',
#  'ce',
#  'ghost',
#  'rose',
#  'compelling',
#  'dell',
#  'henry',
#  'moon',
#  'favorite',
#  'miss',
#  'maybe',
#  'led',
#  'challenge',
#  'trip',
#  'worlds',
#  'narrative',
#  'decides',
#  'near',
#  'acclaimed',
#  'rescue',
#  'universe',
#  'challenges',
#  'picture',
#  'kate',
#  'began',
#  'mit',
#  'debut',
#  'becoming',
#  'include',
#  'date',
#  'decades',
#  'william',
#  'ini',
#  'presents',
#  'suo',
#  'highly',
#  'enjoy',
#  'content',
#  ...]

# %%
w2v_model.wv.key_to_index
# Out:
# {'the': 0,
#  'and': 1,
#  'of': 2,
#  'to': 3,
#  'in': 4,
#  'is': 5,
#  'her': 6,
#  'for': 7,
#  'his': 8,
#  'with': 9,
#  'that': 10,
#  'he': 11,
#  'she': 12,
#  'as': 13,
#  'on': 14,
#  'it': 15,
#  'but': 16,
#  'from': 17,
#  'an': 18,
#  'de': 19,
#  'this': 20,
#  'by': 21,
#  'has': 22,
#  'their': 23,
#  'one': 24,
#  'be': 25,
#  'who': 26,
#  'are': 27,
#  'life': 28,
#  'when': 29,
#  'at': 30,
#  'you': 31,
#  'they': 32,
#  'will': 33,
#  'all': 34,
#  'was': 35,
#  'new': 36,
#  'can': 37,
#  'la': 38,
#  'book': 39,
#  'have': 40,
#  'world': 41,
#  'what': 42,
#  'into': 43,
#  'him': 44,
#  'not': 45,
#  'or': 46,
#  'love': 47,
#  'more': 48,
#  'about': 49,
#  'how': 50,
#  'out': 51,
#  'no': 52,
#  'up': 53,
#  'only': 54,
#  'time': 55,
#  'story': 56,
#  'man': 57,
#  'un': 58,
#  'di': 59,
#  'first': 60,
#  'them': 61,
#  'en': 62,
#  'most': 63,
#  'your': 64,
#  'que': 65,
#  'been': 66,
#  'than': 67,
#  'so': 68,
#  'do': 69,
#  'now': 70,
#  'family': 71,
#  'just': 72,
#  'there': 73,
#  'years': 74,
#  'after': 75,
#  'own': 76,
#  'if': 77,
#  'two': 78,
#  'find': 79,
#  'its': 80,
#  'way': 81,
#  'through': 82,
#  'like': 83,
#  'even': 84,
#  'we': 85,
#  'other': 86,
#  'never': 87,
#  'had': 88,
#  'se': 89,
#  'my': 90,
#  'old': 91,
#  'which': 92,
#  'where': 93,
#  'over': 94,
#  'back': 95,
#  'young': 96,
#  'people': 97,
#  'el': 98,
#  'make': 99,
#  'series': 100,
#  'best': 101,
#  'war': 102,
#  'our': 103,
#  'author': 104,
#  'before': 105,
#  'una': 106,
#  'woman': 107,
#  'home': 108,
#  'ever': 109,
#  'get': 110,
#  'these': 111,
#  'work': 112,
#  'must': 113,
#  'heart': 114,
#  'between': 115,
#  'day': 116,
#  'novel': 117,
#  'help': 118,
#  'also': 119,
#  'year': 120,
#  'history': 121,
#  'il': 122,
#  'could': 123,
#  'stories': 124,
#  'would': 125,
#  'some': 126,
#  'past': 127,
#  'each': 128,
#  'le': 129,
#  'both': 130,
#  'me': 131,
#  'long': 132,
#  'well': 133,
#  'da': 134,
#  'lives': 135,
#  'come': 136,
#  'every': 137,
#  'death': 138,
#  'then': 139,
#  'while': 140,
#  'were': 141,
#  'many': 142,
#  'little': 143,
#  'take': 144,
#  'down': 145,
#  'father': 146,
#  'che': 147,
#  'being': 148,
#  'del': 149,
#  'us': 150,
#  'know': 151,
#  'finds': 152,
#  'secret': 153,
#  'die': 154,
#  'everything': 155,
#  'too': 156,
#  'men': 157,
#  'until': 158,
#  'together': 159,
#  'girl': 160,
#  'three': 161,
#  'good': 162,
#  'great': 163,
#  'night': 164,
#  'na': 165,
#  'much': 166,
#  'last': 167,
#  'very': 168,
#  'women': 169,
#  'american': 170,
#  'mother': 171,
#  'may': 172,
#  'friends': 173,
#  'city': 174,
#  'dark': 175,
#  'those': 176,
#  'si': 177,
#  'off': 178,
#  'go': 179,
#  'readers': 180,
#  'friend': 181,
#  'children': 182,
#  'human': 183,
#  'things': 184,
#  'once': 185,
#  'con': 186,
#  've': 187,
#  'los': 188,
#  'school': 189,
#  'herself': 190,
#  'power': 191,
#  'something': 192,
#  'again': 193,
#  'york': 194,
#  'himself': 195,
#  'true': 196,
#  'su': 197,
#  'wants': 198,
#  'set': 199,
#  'why': 200,
#  'away': 201,
#  'son': 202,
#  'place': 203,
#  'town': 204,
#  'against': 205,
#  'become': 206,
#  'll': 207,
#  'any': 208,
#  'knows': 209,
#  'yang': 210,
#  'doesn': 211,
#  'takes': 212,
#  'part': 213,
#  'another': 214,
#  'yet': 215,
#  'books': 216,
#  'dead': 217,
#  'end': 218,
#  'made': 219,
#  'high': 220,
#  'around': 221,
#  'always': 222,
#  'real': 223,
#  'et': 224,
#  'read': 225,
#  're': 226,
#  'comes': 227,
#  'secrets': 228,
#  'still': 229,
#  'god': 230,
#  'romance': 231,
#  'keep': 232,
#  'dan': 233,
#  'want': 234,
#  'house': 235,
#  'behind': 236,
#  'future': 237,
#  'see': 238,
#  'beautiful': 239,
#  'right': 240,
#  'found': 241,
#  'left': 242,
#  'such': 243,
#  'face': 244,
#  'full': 245,
#  'does': 246,
#  'soon': 247,
#  'guide': 248,
#  'lost': 249,
#  'und': 250,
#  'journey': 251,
#  'living': 252,
#  'fy': 253,
#  'murder': 254,
#  'times': 255,
#  'der': 256,
#  'century': 257,
#  'truth': 258,
#  'nothing': 259,
#  'including': 260,
#  'mystery': 261,
#  'edition': 262,
#  'need': 263,
#  'boy': 264,
#  'tale': 265,
#  'learn': 266,
#  'america': 267,
#  'perfect': 268,
#  'far': 269,
#  'save': 270,
#  'under': 271,
#  'don': 272,
#  'without': 273,
#  'change': 274,
#  'live': 275,
#  'since': 276,
#  'collection': 277,
#  'mn': 278,
#  'known': 279,
#  'short': 280,
#  'small': 281,
#  'might': 282,
#  'art': 283,
#  'thing': 284,
#  'written': 285,
#  'es': 286,
#  'al': 287,
#  'powerful': 288,
#  'because': 289,
#  'black': 290,
#  'body': 291,
#  'wife': 292,
#  'makes': 293,
#  'going': 294,
#  'child': 295,
#  'per': 296,
#  'personal': 297,
#  'para': 298,
#  'here': 299,
#  'daughter': 300,
#  'age': 301,
#  'four': 302,
#  'job': 303,
#  'mind': 304,
#  'second': 305,
#  'enough': 306,
#  'thought': 307,
#  'fiction': 308,
#  'really': 309,
#  'finally': 310,
#  'country': 311,
#  'husband': 312,
#  'business': 313,
#  'por': 314,
#  'brother': 315,
#  'john': 316,
#  'modern': 317,
#  'big': 318,
#  'isn': 319,
#  'whose': 320,
#  'different': 321,
#  'chance': 322,
#  'begins': 323,
#  'mysterious': 324,
#  'along': 325,
#  'same': 326,
#  'during': 327,
#  'non': 328,
#  'self': 329,
#  'van': 330,
#  'hard': 331,
#  'king': 332,
#  'look': 333,
#  'hope': 334,
#  'discover': 335,
#  'relationship': 336,
#  'today': 337,
#  'adventure': 338,
#  'next': 339,
#  'someone': 340,
#  'earth': 341,
#  'magic': 342,
#  'dangerous': 343,
#  'las': 344,
#  'les': 345,
#  'case': 346,
#  'days': 347,
#  'turn': 348,
#  'dreams': 349,
#  'needs': 350,
#  'parents': 351,
#  'everyone': 352,
#  'ha': 353,
#  'five': 354,
#  'volume': 355,
#  'seems': 356,
#  'characters': 357,
#  'becomes': 358,
#  'dr': 359,
#  'use': 360,
#  'den': 361,
#  'sister': 362,
#  'making': 363,
#  'free': 364,
#  'bad': 365,
#  'forever': 366,
#  'killer': 367,
#  'discovers': 368,
#  'better': 369,
#  'writing': 370,
#  'science': 371,
#  'should': 372,
#  'social': 373,
#  'determined': 374,
#  'stop': 375,
#  'sex': 376,
#  'though': 377,
#  'des': 378,
#  'did': 379,
#  'give': 380,
#  'marriage': 381,
#  'few': 382,
#  'let': 383,
#  'within': 384,
#  'across': 385,
#  'ancient': 386,
#  'experience': 387,
#  'ten': 388,
#  'others': 389,
#  'easy': 390,
#  'alone': 391,
#  'turns': 392,
#  'put': 393,
#  'side': 394,
#  'battle': 395,
#  'blood': 396,
#  'della': 397,
#  'sa': 398,
#  'order': 399,
#  'london': 400,
#  'words': 401,
#  'anything': 402,
#  'star': 403,
#  'offers': 404,
#  'meets': 405,
#  'career': 406,
#  'game': 407,
#  'published': 408,
#  'een': 409,
#  'anyone': 410,
#  'name': 411,
#  'bir': 412,
#  'um': 413,
#  'society': 414,
#  'bestselling': 415,
#  'light': 416,
#  'christmas': 417,
#  'important': 418,
#  'deep': 419,
#  'political': 420,
#  'white': 421,
#  'ways': 422,
#  'land': 423,
#  'fight': 424,
#  'show': 425,
#  'eyes': 426,
#  'run': 427,
#  'sie': 428,
#  'called': 429,
#  'hot': 430,
#  'ago': 431,
#  'includes': 432,
#  'start': 433,
#  'shows': 434,
#  'crime': 435,
#  'evil': 436,
#  'simple': 437,
#  'control': 438,
#  'tales': 439,
#  'bring': 440,
#  'beyond': 441,
#  'er': 442,
#  'lo': 443,
#  'looking': 444,
#  'original': 445,
#  'fall': 446,
#  'works': 447,
#  'think': 448,
#  'classic': 449,
#  'won': 450,
#  'later': 451,
#  'passion': 452,
#  'themselves': 453,
#  'award': 454,
#  'com': 455,
#  'events': 456,
#  'questions': 457,
#  'summer': 458,
#  'play': 459,
#  'working': 460,
#  'gets': 461,
#  'english': 462,
#  'met': 463,
#  'dream': 464,
#  'sure': 465,
#  'writer': 466,
#  'person': 467,
#  'special': 468,
#  'soul': 469,
#  'language': 470,
#  'plan': 471,
#  'among': 472,
#  'head': 473,
#  'kai': 474,
#  'reading': 475,
#  'jack': 476,
#  'ja': 477,
#  'group': 478,
#  'step': 479,
#  'twenty': 480,
#  'forced': 481,
#  'mas': 482,
#  'strange': 483,
#  'ma': 484,
#  'inside': 485,
#  'complete': 486,
#  'meet': 487,
#  'early': 488,
#  'goes': 489,
#  'detective': 490,
#  'kind': 491,
#  'reader': 492,
#  'une': 493,
#  'however': 494,
#  'return': 495,
#  'team': 496,
#  'money': 497,
#  'trying': 498,
#  'nature': 499,
#  'care': 500,
#  'coming': 501,
#  'james': 502,
#  'means': 503,
#  'wrong': 504,
#  'ne': 505,
#  'often': 506,
#  'sexy': 507,
#  'search': 508,
#  'como': 509,
#  'te': 510,
#  'fun': 511,
#  'six': 512,
#  'escape': 513,
#  'danger': 514,
#  'culture': 515,
#  'getting': 516,
#  'brings': 517,
#  'leave': 518,
#  'trust': 519,
#  'upon': 520,
#  'tell': 521,
#  'loves': 522,
#  'knew': 523,
#  'fate': 524,
#  'former': 525,
#  'master': 526,
#  'du': 527,
#  'st': 528,
#  'tells': 529,
#  'having': 530,
#  'unique': 531,
#  'rich': 532,
#  'course': 533,
#  'police': 534,
#  'historical': 535,
#  'david': 536,
#  'mission': 537,
#  'faith': 538,
#  'close': 539,
#  'greatest': 540,
#  'popular': 541,
#  'able': 542,
#  'het': 543,
#  'je': 544,
#  'wild': 545,
#  'based': 546,
#  'fantasy': 547,
#  'born': 548,
#  'est': 549,
#  'hand': 550,
#  'winning': 551,
#  'island': 552,
#  'sua': 553,
#  'th': 554,
#  'survive': 555,
#  'girls': 556,
#  'protect': 557,
#  'ex': 558,
#  'information': 559,
#  'red': 560,
#  'whole': 561,
#  'fire': 562,
#  'middle': 563,
#  'told': 564,
#  'food': 565,
#  'forces': 566,
#  'beauty': 567,
#  'wanted': 568,
#  'almost': 569,
#  'local': 570,
#  'baby': 571,
#  'call': 572,
#  'missing': 573,
#  'hidden': 574,
#  'follow': 575,
#  'vampire': 576,
#  'stay': 577,
#  'hands': 578,
#  'top': 579,
#  'sometimes': 580,
#  'present': 581,
#  'late': 582,
#  'loved': 583,
#  'whether': 584,
#  'feel': 585,
#  'deadly': 586,
#  'understand': 587,
#  'key': 588,
#  'believe': 589,
#  'final': 590,
#  'used': 591,
#  'desire': 592,
#  'state': 593,
#  'college': 594,
#  'mr': 595,
#  'got': 596,
#  'action': 597,
#  'och': 598,
#  'das': 599,
#  'half': 600,
#  'single': 601,
#  'didn': 602,
#  'force': 603,
#  'fear': 604,
#  'lead': 605,
#  'ready': 606,
#  'lady': 607,
#  'moment': 608,
#  'taking': 609,
#  'seen': 610,
#  'sense': 611,
#  'finding': 612,
#  'race': 613,
#  'filled': 614,
#  'happy': 615,
#  'famous': 616,
#  'choice': 617,
#  'hell': 618,
#  'matter': 619,
#  'music': 620,
#  'turned': 621,
#  'lies': 622,
#  'taken': 623,
#  'clear': 624,
#  'childhood': 625,
#  'contains': 626,
#  'growing': 627,
#  'england': 628,
#  'law': 629,
#  'community': 630,
#  'reality': 631,
#  'spirit': 632,
#  'learns': 633,
#  'especially': 634,
#  'say': 635,
#  'west': 636,
#  'research': 637,
#  'strong': 638,
#  'major': 639,
#  'tou': 640,
#  'public': 641,
#  'move': 642,
#  'provides': 643,
#  'contemporary': 644,
#  'cover': 645,
#  'uma': 646,
#  'suddenly': 647,
#  'using': 648,
#  'beginning': 649,
#  'question': 650,
#  'space': 651,
#  'fast': 652,
#  'queen': 653,
#  'account': 654,
#  'extraordinary': 655,
#  'came': 656,
#  'dog': 657,
#  'sexual': 658,
#  'else': 659,
#  'door': 660,
#  'line': 661,
#  'form': 662,
#  'students': 663,
#  'handsome': 664,
#  'desperate': 665,
#  'novels': 666,
#  'michael': 667,
#  'friendship': 668,
#  'named': 669,
#  'lord': 670,
#  'sea': 671,
#  'broken': 672,
#  'text': 673,
#  'kids': 674,
#  'success': 675,
#  'trouble': 676,
#  'qui': 677,
#  'understanding': 678,
#  'stand': 679,
#  'literary': 680,
#  'running': 681,
#  'plans': 682,
#  'unexpected': 683,
#  'study': 684,
#  'create': 685,
#  'problem': 686,
#  'apart': 687,
#  'begin': 688,
#  'became': 689,
#  'seven': 690,
#  'page': 691,
#  'poems': 692,
#  'era': 693,
#  'states': 694,
#  'idea': 695,
#  'club': 696,
#  'alive': 697,
#  'writers': 698,
#  'break': 699,
#  'kill': 700,
#  'moving': 701,
#  'style': 702,
#  'adventures': 703,
#  'plus': 704,
#  'fact': 705,
#  'gives': 706,
#  'roman': 707,
#  'fans': 708,
#  'em': 709,
#  'south': 710,
#  'gone': 711,
#  'despite': 712,
#  'road': 713,
#  'peace': 714,
#  'enemy': 715,
#  'path': 716,
#  'quest': 717,
#  'open': 718,
#  'safe': 719,
#  'changed': 720,
#  'north': 721,
#  'planet': 722,
#  'freedom': 723,
#  'changes': 724,
#  'literature': 725,
#  'word': 726,
#  'united': 727,
#  'leads': 728,
#  'loss': 729,
#  'company': 730,
#  'cold': 731,
#  'fascinating': 732,
#  'instead': 733,
#  'national': 734,
#  'beloved': 735,
#  'zu': 736,
#  'point': 737,
#  'struggle': 738,
#  'eye': 739,
#  'ideas': 740,
#  'less': 741,
#  'lm': 742,
#  'introduction': 743,
#  'hero': 744,
#  'church': 745,
#  'role': 746,
#  'class': 747,
#  'sin': 748,
#  'vida': 749,
#  'falls': 750,
#  'travel': 751,
#  'entire': 752,
#  'piu': 753,
#  'ist': 754,
#  'authors': 755,
#  'british': 756,
#  'og': 757,
#  'possible': 758,
#  'drawn': 759,
#  'share': 760,
#  'dans': 761,
#  'successful': 762,
#  'street': 763,
#  'sus': 764,
#  'learning': 765,
#  'reveals': 766,
#  'pages': 767,
#  'sweet': 768,
#  'government': 769,
#  'blue': 770,
#  'ze': 771,
#  'funny': 772,
#  'quickly': 773,
#  'esta': 774,
#  'cat': 775,
#  'private': 776,
#  'thriller': 777,
#  'party': 778,
#  'brought': 779,
#  'color': 780,
#  'already': 781,
#  'answers': 782,
#  'voice': 783,
#  'room': 784,
#  'explores': 785,
#  'international': 786,
#  'risk': 787,
#  'rock': 788,
#  'als': 789,
#  'itself': 790,
#  'prince': 791,
#  'poetry': 792,
#  'throughout': 793,
#  'humor': 794,
#  'mary': 795,
#  'recipes': 796,
#  'issues': 797,
#  'violence': 798,
#  'problems': 799,
#  'robert': 800,
#  'grace': 801,
#  'army': 802,
#  'given': 803,
#  'months': 804,
#  'darkness': 805,
#  'alla': 806,
#  'christian': 807,
#  'returns': 808,
#  'brilliant': 809,
#  'sets': 810,
#  'knowledge': 811,
#  'am': 812,
#  'rules': 813,
#  'practical': 814,
#  'military': 815,
#  'happens': 816,
#  'decide': 817,
#  'lived': 818,
#  'following': 819,
#  'destroy': 820,
#  'created': 821,
#  'truly': 822,
#  'von': 823,
#  'som': 824,
#  'join': 825,
#  'guy': 826,
#  'gift': 827,
#  'ein': 828,
#  'co': 829,
#  'killed': 830,
#  'caught': 831,
#  'artist': 832,
#  'spiritual': 833,
#  'magical': 834,
#  'available': 835,
#  'mark': 836,
#  'identity': 837,
#  'boys': 838,
#  'romantic': 839,
#  'looks': 840,
#  'doctor': 841,
#  'sam': 842,
#  'stranger': 843,
#  'features': 844,
#  'health': 845,
#  'han': 846,
#  'hold': 847,
#  'system': 848,
#  'mais': 849,
#  'memories': 850,
#  'nearly': 851,
#  'seem': 852,
#  'film': 853,
#  'brothers': 854,
#  'feelings': 855,
#  'justice': 856,
#  'deal': 857,
#  'dengan': 858,
#  'powers': 859,
#  'falling': 860,
#  'trilogy': 861,
#  'process': 862,
#  'thinks': 863,
#  'horror': 864,
#  'leading': 865,
#  'tes': 866,
#  'lover': 867,
#  'leaving': 868,
#  'boyfriend': 869,
#  'common': 870,
#  'worse': 871,
#  'revenge': 872,
#  'relationships': 873,
#  'empire': 874,
#  'epic': 875,
#  'peter': 876,
#  'student': 877,
#  'os': 878,
#  'done': 879,
#  'feels': 880,
#  'realizes': 881,
#  'wedding': 882,
#  'fresh': 883,
#  'ii': 884,
#  'win': 885,
#  'fighting': 886,
#  'illustrations': 887,
#  'sees': 888,
#  'om': 889,
#  'village': 890,
#  'pain': 891,
#  'third': 892,
#  'paul': 893,
#  'offer': 894,
#  'chapter': 895,
#  'pero': 896,
#  'lot': 897,
#  'took': 898,
#  'sich': 899,
#  'adult': 900,
#  'french': 901,
#  'alex': 902,
#  'dragon': 903,
#  'struggles': 904,
#  'ultimate': 905,
#  'skills': 906,
#  'experiences': 907,
#  'jane': 908,
#  'cultural': 909,
#  'elle': 910,
#  'least': 911,
#  'leaves': 912,
#  'natural': 913,
#  'nation': 914,
#  'married': 915,
#  'doing': 916,
#  'outside': 917,
#  'terrible': 918,
#  'ar': 919,
#  'starts': 920,
#  'try': 921,
#  'character': 922,
#  'agent': 923,
#  'memory': 924,
#  'politics': 925,
#  'ben': 926,
#  'pa': 927,
#  'figure': 928,
#  'prove': 929,
#  'george': 930,
#  'longer': 931,
#  'happened': 932,
#  'rest': 933,
#  'paris': 934,
#  'rise': 935,
#  'dei': 936,
#  'tragedy': 937,
#  'za': 938,
#  'tom': 939,
#  'ta': 940,
#  'lose': 941,
#  'rather': 942,
#  'survival': 943,
#  'green': 944,
#  'wolf': 945,
#  'water': 946,
#  'places': 947,
#  'civil': 948,
#  'discovery': 949,
#  'attention': 950,
#  'thomas': 951,
#  'nel': 952,
#  'pour': 953,
#  'edge': 954,
#  'said': 955,
#  'illustrated': 956,
#  'spent': 957,
#  'media': 958,
#  'cannot': 959,
#  'destiny': 960,
#  'university': 961,
#  'remarkable': 962,
#  'ce': 963,
#  'ghost': 964,
#  'rose': 965,
#  'compelling': 966,
#  'dell': 967,
#  'henry': 968,
#  'moon': 969,
#  'favorite': 970,
#  'miss': 971,
#  'maybe': 972,
#  'led': 973,
#  'challenge': 974,
#  'trip': 975,
#  'worlds': 976,
#  'narrative': 977,
#  'decides': 978,
#  'near': 979,
#  'acclaimed': 980,
#  'rescue': 981,
#  'universe': 982,
#  'challenges': 983,
#  'picture': 984,
#  'kate': 985,
#  'began': 986,
#  'mit': 987,
#  'debut': 988,
#  'becoming': 989,
#  'include': 990,
#  'date': 991,
#  'decades': 992,
#  'william': 993,
#  'ini': 994,
#  'presents': 995,
#  'suo': 996,
#  'highly': 997,
#  'enjoy': 998,
#  'content': 999,
#  ...}

# %%
for index, word in enumerate(w2v_model.wv.index_to_key):
    if index == 10:
        break
    print(f"word #{index}/{len(w2v_model.wv.index_to_key)} is {word}")
# Out:
# word #0/245474 is the
# word #1/245474 is and
# word #2/245474 is of
# word #3/245474 is to
# word #4/245474 is in
# word #5/245474 is is
# word #6/245474 is her
# word #7/245474 is for
# word #8/245474 is his
# word #9/245474 is with
